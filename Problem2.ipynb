# %% [markdown]
# ---
# ---
# ---
# <a name="COMPILE"></a>
# ## C) Make `torch.compile` work without graph breaks for QLoRA [Difficulty: Easy to Medium] [Max points: 9]
#
# 1. Goal: Write a single Python script like task B), except the goal is to `torch.compile` all modules if possible.
#
# 2. There must NOT be graph breaks, and excessive re-compilations should not be seen.
#
# 3. You should have say max 30 compilations. Over 60 is definitely wrong.
#
# 4. The loss must match with the non compiled module.
#
# 5. Utilize patching as much as possible.
#
# 6. Think about which areas might need disabling for compilation. Think about regional compilation. How do we compile sections efficiently?
#
# 7. Log memory / VRAM usage, and monitor speedups as well.
#
# 8. Must work for QLoRA.
#
# We provided a script below, and showcased how to detect if graph breaks are seen. We also torch compiled the MLP for Llama:

# %%
import torch
torch_compile_options = torch_compile_options = {
    "epilogue_fusion"   : True,
    "max_autotune"      : True,
    "shape_padding"     : True,
    "trace.enabled"     : True,
    "triton.cudagraphs" : False,
}

@torch.compile(fullgraph = False, dynamic = True, options = torch_compile_options)
def compiled_llama_mlp(self, x):
    down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
    return down_proj

import transformers.models.llama.modeling_llama
transformers.models.llama.modeling_llama.LlamaMLP.forward = compiled_llama_mlp

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import get_peft_model, LoraConfig, TaskType
os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = \
    "expandable_segments:True,"\
    "roundup_power2_divisions:[32:256,64:128,256:64,>:32]"

max_seq_length = 1024
torch.set_default_dtype(torch.float16)
model_name = "unsloth/Llama-3.2-1B-Instruct-bnb-4bit"
dtype = torch.float16
bnb_config = BitsAndBytesConfig(
    load_in_4bit              = True,
    bnb_4bit_use_double_quant = True,
    bnb_4bit_quant_type       = "nf4",
    bnb_4bit_compute_dtype    = dtype,
)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map = "auto",
    attn_implementation = "sdpa",
    quantization_config = bnb_config,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.padding_side = "right"

lora_config = LoraConfig(
    r = 32,
    lora_alpha = 64,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],
    lora_dropout = 0,
    bias = "none",
    task_type = TaskType.CAUSAL_LM,
)

# Get LoRA and setup model
model = get_peft_model(model, lora_config)
with torch.no_grad():
    for name, param in model.named_parameters():
        if ".lora_A." in name or ".lora_B." in name: param.requires_grad_(True)
        else: param.requires_grad_(False)

# Currently GC will cause torch.compile to be disabled, so disable it
# model.gradient_checkpointing_enable()
model.enable_input_require_grads()

# Get dataset
from datasets import load_dataset
from trl import SFTTrainer, SFTConfig
url = "https://huggingface.co/datasets/laion/OIG/resolve/main/unified_chip2.jsonl"
dataset = load_dataset("json", data_files = {"train" : url}, split = "train[:10%]")
# Out:
# config.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# model.safetensors:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.7k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]

# %% [markdown]
# We provide full logging for `torch.compile` like below:

# %%
# Must show all graph breaks are not seen with torch.compile
import os
os.environ["TORCHDYNAMO_VERBOSE"] = "1"
os.environ["TORCHINDUCTOR_FORCE_DISABLE_CACHES"] = "1"
os.environ["TORCHINDUCTOR_COMPILE_THREADS"] = "1"

import logging
torch._inductor.config.debug = True
torch._logging.set_logs(
    dynamo = logging.WARN,
    inductor = logging.WARN,
    graph_breaks = True,
    recompiles = True,
    recompiles_verbose = True,
    compiled_autograd_verbose = True,
    # aot_joint_graph = True, # Enable for more logs
    # aot_graphs = True,
)
torch._dynamo.config.verbose = True
torch._dynamo.config.suppress_errors = False

# %% [markdown]
# When we execute the code below, we can see graph breaks - remove them.

# %%
trainer = SFTTrainer(
    model = model,
    train_dataset = dataset,
    processing_class = tokenizer,
    args = SFTConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 2,
        warmup_steps = 1,
        max_steps = 10,
        logging_steps = 1,
        output_dir = "outputs",
        seed = 3407,
        max_seq_length = max_seq_length,
        fp16 = model.get_input_embeddings().weight.dtype == torch.float16,
        bf16 = model.get_input_embeddings().weight.dtype == torch.bfloat16,
        report_to = "none", # For W&B
        dataset_num_proc = 4,
    ),
)
trainer.train()
# Out:
# Applying chat template to train dataset (num_proc=4):   0%|          | 0/21029 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=4):   0%|          | 0/21029 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=4):   0%|          | 0/21029 [00:00<?, ? examples/s]
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks] Graph break: from user code at:
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "<ipython-input-12-7786d8f77241>", line 12, in compiled_llama_mlp
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py", line 496, in forward
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     result = self.base_layer(x, *args, **kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks] Traceback (most recent call last):
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 156, in realize_and_forward
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 899, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     tracer.run()
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     while self.step():
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1680, in CALL_FUNCTION_EX
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.call_function(fn, argsvars.items, kwargsvars)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 156, in realize_and_forward
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 899, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     tracer.run()
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     while self.step():
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1024, in call_function
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 796, in call_method
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 343, in call_method
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 297, in unimplemented
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0216 08:42:10.741000 431 torch/_dynamo/symbolic_convert.py:617] [0/0] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks] Graph break: from user code at:
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py", line 496, in forward
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     result = self.base_layer(x, *args, **kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks] Traceback (most recent call last):
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1680, in CALL_FUNCTION_EX
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self.call_function(fn, argsvars.items, kwargsvars)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 156, in realize_and_forward
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 899, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     tracer.run()
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     while self.step():
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1024, in call_function
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 796, in call_method
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 343, in call_method
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 297, in unimplemented
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0216 08:42:10.839000 431 torch/_dynamo/symbolic_convert.py:617] [1/0] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks] Graph break: from user code at:
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py", line 484, in forward
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     return bnb.matmul_4bit(x, self.weight.t(), bias=bias, quant_state=self.weight.quant_state).to(inp_dtype)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks] Traceback (most recent call last):
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1024, in call_function
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 796, in call_method
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 343, in call_method
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 297, in unimplemented
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0216 08:42:10.916000 431 torch/_dynamo/symbolic_convert.py:617] [2/0] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# W0216 08:42:15.086000 431 torch/_inductor/debug.py:434] [2/0_1] model__0_forward_1 debug trace: /content/torch_compile_debug/run_2025_02_16_08_42_11_952744-pid_431/torchinductor/model__0_forward_1.0
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks] Graph break: from user code at:
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py", line 533, in matmul_4bit
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return MatMul4Bit.apply(A, B, out, bias, quant_state)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/autograd/_functions.py", line 462, in forward
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     output = torch.nn.functional.linear(A, F.dequantize_4bit(B, quant_state).to(A.dtype).t(), bias)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/functional.py", line 1352, in dequantize_4bit
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     absmax = dequantize_blockwise(quant_state.absmax, quant_state.state2)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/functional.py", line 1029, in dequantize_blockwise
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     get_ptr(quant_state.code),
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/bitsandbytes/functional.py", line 497, in get_ptr
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return ct.c_void_p(A.data_ptr())
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks] Traceback (most recent call last):
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1024, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 774, in call_method
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return self.call_apply(tx, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 699, in call_apply
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     ).call_function(tx, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/higher_order_ops.py", line 2015, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     (fwd_out, _), fwd_graph, fwd_freevars = speculate_subgraph(
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]                                             ^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/higher_order_ops.py", line 533, in speculate_subgraph
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     raise ex
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/higher_order_ops.py", line 462, in speculate_subgraph
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     output = f.call_function(tx, args, sub_kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     tracer.run()
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     while self.step():
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     tracer.run()
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     while self.step():
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:15.255000 431 torch/_dynamo/symbolic_convert.py:617] [5/0] [__graph_breaks]     tracer.run()
# ...
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 156, in realize_and_forward
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 899, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     tracer.run()
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     while self.step():
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 1680, in CALL_FUNCTION_EX
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.call_function(fn, argsvars.items, kwargsvars)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/lazy.py", line 156, in realize_and_forward
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return getattr(self.realize(), name)(*args, **kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/nn_module.py", line 899, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return variables.UserFunctionVariable(fn, source=source).call_function(
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 324, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return super().call_function(tx, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/functions.py", line 111, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return tx.inline_user_function_return(self, [*self.self_args(), *args], kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 836, in inline_user_function_return
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return InliningInstructionTranslator.inline_call(self, fn, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3011, in inline_call
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return cls.inline_call_(parent, func, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 3139, in inline_call_
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     tracer.run()
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 983, in run
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     while self.step():
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]           ^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 895, in step
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.dispatch_table[inst.opcode](self, inst)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 582, in wrapper
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return inner_fn(self, inst)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2279, in CALL
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self._call(inst)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 2273, in _call
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.call_function(fn, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/symbolic_convert.py", line 830, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     self.push(fn.call_function(self, args, kwargs))  # type: ignore[arg-type]
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/misc.py", line 1024, in call_function
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return self.obj.call_method(tx, self.name, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/user_defined.py", line 796, in call_method
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     return super().call_method(tx, name, args, kwargs)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/variables/base.py", line 343, in call_method
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     unimplemented(f"call_method {self} {name} {args} {kwargs}")
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]   File "/usr/local/lib/python3.11/dist-packages/torch/_dynamo/exc.py", line 297, in unimplemented
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks]     raise Unsupported(msg, case_name=case_name)
# V0216 08:42:21.898000 431 torch/_dynamo/symbolic_convert.py:617] [26/0] [__graph_breaks] torch._dynamo.exc.Unsupported: call_method UserDefinedObjectVariable(Params4bit) t [] {}
# W0216 08:42:22.236000 431 torch/_inductor/debug.py:434] [26/0_1] model__10_forward_16 debug trace: /content/torch_compile_debug/run_2025_02_16_08_42_11_952744-pid_431/torchinductor/model__10_forward_16.12
# W0216 08:42:22.689000 431 torch/_inductor/debug.py:434] [26/0_1] model__10_backward_17 debug trace: /content/torch_compile_debug/run_2025_02_16_08_42_11_952744-pid_431/torchinductor/model__10_backward_17.13
# V0216 08:42:22.814000 431 torch/_dynamo/guards.py:2811] [24/1] [__recompiles_verbose] Recompiling function torch_dynamo_resume_in_forward_at_496 in /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:496
# V0216 08:42:22.814000 431 torch/_dynamo/guards.py:2811] [24/1] [__recompiles_verbose]     triggered by the following guard failure(s):
# V0216 08:42:22.814000 431 torch/_dynamo/guards.py:2811] [24/1] [__recompiles_verbose]     guard 0 failures:
# V0216 08:42:22.814000 431 torch/_dynamo/guards.py:2811] [24/1] [__recompiles_verbose]     - 24/0: tensor 'L['x']' size mismatch at index 2. expected 2048, actual 8192
# W0216 08:42:23.242000 431 torch/_inductor/debug.py:434] [24/1] model__11_forward_19 debug trace: /content/torch_compile_debug/run_2025_02_16_08_42_11_952744-pid_431/torchinductor/model__11_forward_19.14
# W0216 08:42:23.390000 431 torch/_inductor/debug.py:434] [24/1] model__11_backward_20 debug trace: /content/torch_compile_debug/run_2025_02_16_08_42_11_952744-pid_431/torchinductor/model__11_backward_20.15
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:05, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.518500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.392600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.502200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.534700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.137900</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.978900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.248600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.630300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.223300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.688000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10, training_loss=2.385506796836853, metrics={'train_runtime': 20.4527, 'train_samples_per_second': 0.978, 'train_steps_per_second': 0.489, 'total_flos': 10592155496448.0, 'train_loss': 2.385506796836853})

# %% [markdown]
# Log all your steps for debugging in a Colab (maybe this one). Edward's blog http://blog.ezyang.com/, Horace's blogs https://www.thonking.ai/, Slaying OOMs by Jane & Mark: ttps://www.youtube.com/watch?v=UvRl4ansfCg could be useful.

# %% [markdown]
# ## Marking Criteria for C) Max points = 9
# ```python
# if attemped_C:
#     C_score = 0
#     if uses_flex_attention:
#         if dynamic_sequence_length_works: C_score += 3
#         else: C_score += 1
#     if no_torch_compile_BnB: C_score -= 2
#     elif use_part_A: C_score += 1
#     elif torch_compile_BnB: C_score += 1
#
#     if attention_compiled:
#         if excessive_recompilation: C_score -= 3
#         else: C_score += 2
#     if mlp_compiled:
#         if excessive_recompilation: C_score -= 3
#         C_score += 1
#
#     if not loss_compiled: C_score -= 1
#     if not layernorms_compiled: C_score -= 3
#
#     if max_autotune_triton_matmul:
#         if excessive_recompilation: C_score -= 2
#         else: C_score += 2
#
#     final_score += C_score
# else:
#     final_score -= 1
# ```
